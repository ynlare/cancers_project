# %%
import pandas as pd 

import matplotlib.pyplot as plt 

import seaborn as sns

# %%
## Import dataset cancer_b

cancerb = pd.read_csv('/Users/Yedou/Desktop/HistgramCancer/cancer_b.csv')

cancerb.head()
# Out:
#          Id Diagnosis  Radius (mean)  Texture (mean)  Perimeter (mean)  \
# 0   8510426         B         13.540           14.36             87.46
# 1   8510653         B         13.080           15.71             85.63
# 2   8510824         B          9.504           12.44             60.34
# 3    854941         B         13.030           18.42             82.61
# 4  85713702         B          8.196           16.84             51.71
#
#    Area (mean)  Smoothness (mean)  Compactness (mean)  Concavity (mean)  \
# 0        566.3            0.09779             0.08129           0.06664
# 1        520.0            0.10750             0.12700           0.04568
# 2        273.9            0.10240             0.06492           0.02956
# 3        523.8            0.08983             0.03766           0.02562
# 4        201.9            0.08600             0.05943           0.01588
#
#    Concave points (mean)  ...  Radius (worst)  Texture (worst)  \
# ...

# %%
# change Index cancer_b to id

cancerb.set_index('Id', inplace = True)

# %%
cancerb.head() # The first five lines
# Out:
#          Diagnosis  Radius (mean)  Texture (mean)  Perimeter (mean)  \
# Id
# 8510426          B         13.540           14.36             87.46
# 8510653          B         13.080           15.71             85.63
# 8510824          B          9.504           12.44             60.34
# 854941           B         13.030           18.42             82.61
# 85713702         B          8.196           16.84             51.71
#
#           Area (mean)  Smoothness (mean)  Compactness (mean)  \
# Id
# 8510426         566.3            0.09779             0.08129
# 8510653         520.0            0.10750             0.12700
# 8510824         273.9            0.10240             0.06492
# 854941          523.8            0.08983             0.03766
# 85713702        201.9            0.08600             0.05943
#
#           Concavity (mean)  Concave points (mean)  Symmetry (mean)  ...  \
# Id                                                                  ...
# ...

# %%
## Import dataset cancer_m

cancerm = pd.read_csv('/Users/Yedou/Desktop/HistgramCancer/cancer_m.csv')

cancerm.head()
# Out:
#          Id Diagnosis  Radius (mean)  Texture (mean)  Perimeter (mean)  \
# 0    842302         M          17.99           10.38            122.80
# 1    842517         M          20.57           17.77            132.90
# 2  84300903         M          19.69           21.25            130.00
# 3  84348301         M          11.42           20.38             77.58
# 4  84358402         M          20.29           14.34            135.10
#
#    Area (mean)  Smoothness (mean)  Compactness (mean)  Concavity (mean)  \
# 0       1001.0            0.11840             0.27760            0.3001
# 1       1326.0            0.08474             0.07864            0.0869
# 2       1203.0            0.10960             0.15990            0.1974
# 3        386.1            0.14250             0.28390            0.2414
# 4       1297.0            0.10030             0.13280            0.1980
#
#    Concave points (mean)  ...  Radius (worst)  Texture (worst)  \
# ...

# %%
cancerb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 357 entries, 8510426 to 92751
# Data columns (total 31 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Diagnosis                  357 non-null    object
#  1   Radius (mean)              357 non-null    float64
#  2   Texture (mean)             357 non-null    float64
#  3   Perimeter (mean)           357 non-null    float64
#  4   Area (mean)                357 non-null    float64
#  5   Smoothness (mean)          357 non-null    float64
#  6   Compactness (mean)         357 non-null    float64
#  7   Concavity (mean)           357 non-null    float64
#  8   Concave points (mean)      357 non-null    float64
#  9   Symmetry (mean)            357 non-null    float64
#  10  Fractal dimension (mean)   357 non-null    float64
#  11  Radius (se)                357 non-null    float64
#  12  Texture (se)               357 non-null    float64
# ...

# %%
cancerm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 212 entries, 842302 to 927241
# Data columns (total 31 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Diagnosis                  212 non-null    object
#  1   Radius (mean)              212 non-null    float64
#  2   Texture (mean)             212 non-null    float64
#  3   Perimeter (mean)           212 non-null    float64
#  4   Area (mean)                212 non-null    float64
#  5   Smoothness (mean)          212 non-null    float64
#  6   Compactness (mean)         212 non-null    float64
#  7   Concavity (mean)           212 non-null    float64
#  8   Concave points (mean)      212 non-null    float64
#  9   Symmetry (mean)            212 non-null    float64
#  10  Fractal dimension (mean)   212 non-null    float64
#  11  Radius (se)                212 non-null    float64
#  12  Texture (se)               212 non-null    float64
# ...

# %%
# # change Index cancer_m to id
cancerm.set_index('Id', inplace = True)

# %%
cancerm.head() # The first five lines
# Out:
#          Diagnosis  Radius (mean)  Texture (mean)  Perimeter (mean)  \
# Id
# 842302           M          17.99           10.38            122.80
# 842517           M          20.57           17.77            132.90
# 84300903         M          19.69           21.25            130.00
# 84348301         M          11.42           20.38             77.58
# 84358402         M          20.29           14.34            135.10
#
#           Area (mean)  Smoothness (mean)  Compactness (mean)  \
# Id
# 842302         1001.0            0.11840             0.27760
# 842517         1326.0            0.08474             0.07864
# 84300903       1203.0            0.10960             0.15990
# 84348301        386.1            0.14250             0.28390
# 84358402       1297.0            0.10030             0.13280
#
#           Concavity (mean)  Concave points (mean)  Symmetry (mean)  ...  \
# Id                                                                  ...
# ...

# %%
# Histogram of cancerb and cancerm on the same figure 
#  mean representation 

plt.figure( figsize = (10,5))

sns.distplot(a = cancerb['Area (mean)'], label = 'Benigne',kde = False)

sns.distplot(a = cancerm['Area (mean)'], label = 'Maligne',kde = False)

plt.legend()

plt.show()

# %%
# worst representation

plt.figure( figsize = (10,5))

sns.distplot(a = cancerb['Area (worst)'], label = 'Benigne',kde = False)

sns.distplot(a = cancerm['Area (worst)'], label = 'Maligne',kde = False)

plt.legend()

plt.show()

# %%
#  mean kde Plot

plt.figure( figsize = (10,6))

sns.kdeplot(data = cancerb['Area (mean)'], label = 'Benigne',shade = True)

sns.kdeplot(data = cancerm['Area (mean)'], label = 'Maligne',shade = True)

plt.legend()

plt.show()

# %%
#  worst kde Plot

plt.figure( figsize = (10,6))

sns.kdeplot(data = cancerb['Area (worst)'], label = 'Benigne',shade = True)

sns.kdeplot(data = cancerm['Area (worst)'], label = 'Maligne',shade = True)

plt.legend()

plt.show()
